# %% [markdown]
# <p><strong>Objective:</strong> To build a model that can classify the total number of goals scored in a soccer match, given publicly available data</p>
# <p><strong>Performance criteria:</strong> F1 score</p>

# %%
path = r"C:\Machine_learning_datafiles\footballPrediction"

# %%
import os, gc, warnings
warnings.filterwarnings('ignore')

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Machine_learning_datafiles\\footballPrediction'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('training_data.csv', sep=';')
valid = pd.read_csv('validation_data.csv', sep=';')
test = pd.read_csv('testing_data.csv', sep=';')

# %%
train.shape, test.shape, valid.shape
# Out:
# ((100000, 102), (500, 101), (50000, 102))

# %%
teams = pd.Series(list(set(train.teams_home_team_id).union(set(train.teams_away_team_id))))

# %%
print('There are a total of {:,} teams in the dataset.'.format(len(teams)))
# Out:
# There are a total of 10,885 teams in the dataset.

# %%
print('Total number of leagues are {:,}'.format(train.league_name.nunique()))
# Out:
# Total number of leagues are 562

# %% [markdown]
# <b>Data Cleaning</b>

# %%
# dropping Duplicate rows
train = train.drop_duplicates()

# %%
print('Train set after removing duplicates is {:,}'.format(train.shape[0]))
# Out:
# Train set after removing duplicates is 99,536

# %%
# replacing row with % and with nan
for data_df in [train, test, valid]:
    data_df.loc[
        :, 'winning_percent_home':'teams_away_last_5_matches_def'] = data_df.loc[
        :, 'winning_percent_home':'teams_away_last_5_matches_def'].apply(
        lambda x: pd.to_numeric(x.replace('[%nan]', '', regex=True)))

# %%
# replacing -NAN.5
for data_df in [train, test, valid]:
    data_df.loc[:, ['goals_home','goals_away']] = data_df.loc[
        :, ['goals_home','goals_away']].apply(lambda x: x.replace('.[0-9]', np.nan, regex=True))

# %%
for data_df in [train, test, valid]:
    data_df['fixture_date'] = pd.to_datetime(data_df.fixture_date, format='%Y-%m-%d')
    data_df['fixture_year'] = data_df.fixture_date.dt.isocalendar().year
    data_df['fixture_week'] = data_df.fixture_date.dt.isocalendar().week
    data_df['fixture_day'] = data_df.fixture_date.dt.isocalendar().day
    data_df['fixture_month'] = data_df.fixture_date.dt.month
    data_df['fixture_weekday'] = data_df.fixture_date.dt.weekday

# %% [markdown]
# Checking if home and away teams are the same

# %%
ishomeaway = pd.DataFrame()

# %%
ishomeaway['ishome'] = (train.teams_home_team_id == train.teams_home_team_id) * 1
ishomeaway['isAway'] = (train.teams_home_team_id == train.teams_away_team_id) * 1

# %%
print(ishomeaway.isAway.value_counts())
print(ishomeaway.ishome.value_counts())
# Out:
# 0    99531
# 1        5
# Name: isAway, dtype: int64
# 1    99536
# Name: ishome, dtype: int64

# %%
ishomeaway[(ishomeaway.isAway == 1)]
# Out:
#        ishome  isAway
# 3827        1       1
# 6579        1       1
# 12643       1       1
# 14276       1       1
# 78053       1       1

# %%
# let's confirm
train.loc[[3827,6579, 12643, 14276, 78053], :]
# Out:
#        fixture_id  teams_home_team_id  teams_away_team_id  \
# 3827       618759                1405                1405
# 6579       618759                1405                1405
# 12643      636846                9810                9810
# 14276      259490                1405                1405
# 78053      177710                4459                4459
#
#                    fixture_date                          fixture_venue  \
# 3827  2020-10-16 17:09:00+00:00                         Sportplatz KAC
# 6579  2020-10-16 17:09:00+00:00                         Sportplatz KAC
# 12643 2020-11-22 00:00:00+00:00                                    NaN
# 14276 2019-08-23 17:00:00+00:00                   Sportplatz Welzenegg
# 78053 2019-05-12 07:30:00+00:00  Kowloon Tsai Park - Field 1 (Kowloon)
#
#        league_id                  league_name league_country  league_season  \
# 3827        2909         Landesliga - Karnten        Austria           2020
# 6579        2909         Landesliga - Karnten        Austria           2020
# 12643       2991  Tercera Division - Group 13          Spain           2020
# 14276       1088         Landesliga - Karnten        Austria           2019
# 78053        630            HKFA 1st Division      Hong-Kong           2018
#
#               league_round                  home_team_venue_name  \
# 3827          Kärnten - 12                        Sportplatz KAC
# 6579          Kärnten - 12                        Sportplatz KAC
# 12643         Group 13 - 6         Estadio Municipal Cartagonova
# 14276          Kärnten - 5                        Sportplatz KAC
# 78053  Regular Season - 26  Tuen Mun Tang Shiu Kin Sports Ground
#
#       home_team_venue_city  home_team_venue_capacity home_team_country  \
# 3827            Klagenfurt                    2000.0           Austria
# 6579            Klagenfurt                    2000.0           Austria
# 12643            Cartagena                   15105.0             Spain
# 14276           Klagenfurt                    2000.0           Austria
# 78053             Tuen Mun                    2500.0         Hong-Kong
#
#        home_team_founded                  away_team_venue_name  \
# 3827                 NaN                        Sportplatz KAC
# 6579                 NaN                        Sportplatz KAC
# 12643                NaN         Estadio Municipal Cartagonova
# 14276                NaN                        Sportplatz KAC
# 78053             1960.0  Tuen Mun Tang Shiu Kin Sports Ground
#
#       away_team_venue_city  away_team_venue_capacity away_team_country  \
# 3827            Klagenfurt                    2000.0           Austria
# 6579            Klagenfurt                    2000.0           Austria
# 12643            Cartagena                   15105.0             Spain
# 14276           Klagenfurt                    2000.0           Austria
# 78053             Tuen Mun                    2500.0         Hong-Kong
#
#        away_team_founded match_winner  under_over  goals_home  goals_away  \
# 3827                 NaN          N 2         NaN        -2.5        -2.5
# 6579                 NaN          N 2         NaN        -2.5        -2.5
# 12643                NaN          1 N        -3.5        -2.5        -1.5
# 14276                NaN          NaN         NaN         NaN         NaN
# 78053             1960.0          NaN         NaN         NaN         NaN
#
#        winning_percent_home  winning_percent_draws  winning_percent_away  \
# 3827                     10                     45                    45
# 6579                     10                     45                    45
# 12643                    45                     45                    10
# 14276                    33                     33                    33
# 78053                    33                     33                    33
#
#        comparison_forme_home  comparison_forme_away  comparison_att_home  \
# 3827                      50                     50                   50
# 6579                      50                     50                   50
# 12643                     50                     50                   50
# 14276                     50                     50                   50
# 78053                     50                     50                   50
#
#        comparison_att_away  comparison_def_home  comparison_def_away  \
# 3827                    50                   50                   50
# 6579                    50                   50                   50
# 12643                   50                   50                   50
# 14276                   50                   50                   50
# 78053                   50                   50                   50
#
#        comparison_fish_law_home  comparison_fish_law_away  \
# 3827                         25                        75
# 6579                         24                        76
# 12643                        90                        10
# 14276                         0                         0
# 78053                        42                        58
#
#        comparison_h2h_home  comparison_h2h_away  comparison_goals_h2h_home  \
# 3827                    50                   50                         50
# 6579                    50                   50                         50
# 12643                    0                    0                          0
# 14276                   50                   50                         50
# 78053                   50                   50                         50
#
#        comparison_goals_h2h_away  teams_home_last_5_matches_forme  \
# 3827                          50                               47
# 6579                          50                               47
# 12643                          0                               53
# 14276                         50                               33
# 78053                         50                               53
#
#        teams_home_last_5_matches_att  teams_home_last_5_matches_def  \
# 3827                            39.0                           67.0
# 6579                            35.0                           70.0
# 12643                           55.0                           73.0
# 14276                           64.0                           27.0
# 78053                           54.0                           62.0
#
#        teams_away_last_5_matches_forme  teams_away_last_5_matches_att  \
# 3827                                47                           39.0
# 6579                                47                           35.0
# 12643                               53                           55.0
# 14276                               33                           64.0
# 78053                               53                           54.0
#
#        teams_away_last_5_matches_def  teams_home_last_5_matches_goals  \
# 3827                            67.0                                7
# 6579                            70.0                                7
# 12643                           73.0                                6
# 14276                           27.0                                7
# 78053                           62.0                                7
#
#        teams_home_last_5_matches_goals_avg  \
# 3827                                   1.4
# 6579                                   1.4
# 12643                                  1.2
# 14276                                  1.4
# 78053                                  1.4
#
#        teams_home_last_5_matches_goals_against  \
# 3827                                         6
# 6579                                         6
# 12643                                        3
# 14276                                        8
# 78053                                        5
#
#        teams_home_last_5_matches_goals_against_avg  \
# 3827                                           1.2
# 6579                                           1.2
# 12643                                          0.6
# 14276                                          1.6
# 78053                                          1.0
#
#        teams_home_all_last_matches_matchs_matchsPlayed_home  \
# 3827                                                  11
# 6579                                                  11
# 12643                                                  3
# 14276                                                  4
# 78053                                                 25
#
#        teams_home_all_last_matches_matchs_matchsPlayed_away  \
# 3827                                                  11
# 6579                                                  11
# 12643                                                  2
# 14276                                                  4
# 78053                                                 25
#
#        teams_home_all_last_matches_matchs_wins_home  \
# 3827                                              3
# 6579                                              3
# 12643                                             2
# 14276                                             0
# 78053                                             9
#
#        teams_home_all_last_matches_matchs_wins_away  \
# 3827                                              8
# 6579                                              8
# 12643                                             0
# 14276                                             1
# 78053                                             9
#
#        teams_home_all_last_matches_matchs_draws_home  \
# 3827                                               2
# 6579                                               2
# 12643                                              1
# 14276                                              2
# 78053                                              6
#
#        teams_home_all_last_matches_matchs_draws_away  \
# 3827                                               2
# 6579                                               2
# 12643                                              1
# 14276                                              1
# 78053                                              9
#
#        teams_home_all_last_matches_matchs_loses_home  \
# 3827                                               6
# 6579                                               6
# 12643                                              0
# 14276                                              2
# 78053                                             10
#
#        teams_home_all_last_matches_matchs_loses_away  \
# 3827                                               1
# 6579                                               1
# 12643                                              1
# 14276                                              2
# 78053                                              7
#
#        teams_home_all_last_matches_goals_goalsFor_home  \
# 3827                                                18
# 6579                                                18
# 12643                                                5
# 14276                                                4
# 78053                                               40
#
#        teams_home_all_last_matches_goals_goalsFor_away  \
# 3827                                                20
# 6579                                                20
# 12643                                                1
# 14276                                                7
# 78053                                               49
#
#        teams_home_all_last_matches_goals_goalsAgainst_home  \
# 3827                                                  19
# 6579                                                  19
# 12643                                                  1
# 14276                                                  8
# 78053                                                 48
#
#        teams_home_all_last_matches_goals_goalsAgainst_away  \
# 3827                                                   9
# 6579                                                   9
# 12643                                                  2
# 14276                                                  9
# 78053                                                 41
#
#        teams_home_all_last_matches_goalsAvg_goalsFor_home  \
# 3827                                                 1.6
# 6579                                                 1.6
# 12643                                                1.7
# 14276                                                1.0
# 78053                                                1.6
#
#        teams_home_all_last_matches_goalsAvg_goalsFor_away  \
# 3827                                                 1.8
# 6579                                                 1.8
# 12643                                                0.5
# 14276                                                1.8
# 78053                                                2.0
#
#        teams_home_all_last_matches_goalsAvg_goalsAgainst_home  \
# 3827                                                 1.7
# 6579                                                 1.7
# 12643                                                0.3
# 14276                                                2.0
# 78053                                                1.9
#
#        teams_home_all_last_matches_goalsAvg_goalsAgainst_away  \
# 3827                                                 0.8
# 6579                                                 0.8
# 12643                                                1.0
# 14276                                                2.3
# 78053                                                1.6
#
#        teams_home_last_h2h_played_home  teams_home_last_h2h_played_away  \
# 3827                                 9                                9
# 6579                                 9                                9
# 12643                                0                                0
# 14276                                9                                9
# 78053                               10                               10
#
#        teams_home_last_h2h_wins_home  teams_home_last_h2h_wins_away  \
# 3827                               3                              4
# 6579                               3                              4
# 12643                              0                              0
# 14276                              3                              4
# 78053                              3                              3
#
#        teams_home_last_h2h_draws_home  teams_home_last_h2h_draws_away  \
# 3827                                2                               2
# 6579                                2                               2
# 12643                               0                               0
# 14276                               2                               2
# 78053                               4                               4
#
#        teams_home_last_h2h_loses_home  teams_home_last_h2h_loses_away  \
# 3827                                4                               3
# 6579                                4                               3
# 12643                               0                               0
# 14276                               4                               3
# 78053                               3                               3
#
#        teams_away_last_5_matches_goals  teams_away_last_5_matches_goals_avg  \
# 3827                                 7                                  1.4
# 6579                                 7                                  1.4
# 12643                                6                                  1.2
# 14276                                7                                  1.4
# 78053                                7                                  1.4
#
#        teams_away_last_5_matches_goals_against  \
# 3827                                         6
# 6579                                         6
# 12643                                        3
# 14276                                        8
# 78053                                        5
#
#        teams_away_last_5_matches_goals_against_avg  \
# 3827                                           1.2
# 6579                                           1.2
# 12643                                          0.6
# 14276                                          1.6
# 78053                                          1.0
#
#        teams_away_all_last_matches_matchs_matchsPlayed_home  \
# 3827                                                  11
# 6579                                                  11
# 12643                                                  3
# 14276                                                  4
# 78053                                                 25
#
#        teams_away_all_last_matches_matchs_matchsPlayed_away  \
# 3827                                                  11
# 6579                                                  11
# 12643                                                  2
# 14276                                                  4
# 78053                                                 25
#
#        teams_away_all_last_matches_matchs_wins_home  \
# 3827                                              3
# 6579                                              3
# 12643                                             2
# 14276                                             0
# 78053                                             9
#
#        teams_away_all_last_matches_matchs_wins_away  \
# 3827                                              8
# 6579                                              8
# 12643                                             0
# 14276                                             1
# 78053                                             9
#
#        teams_away_all_last_matches_matchs_draws_home  \
# 3827                                               2
# 6579                                               2
# 12643                                              1
# 14276                                              2
# 78053                                              6
#
#        teams_away_all_last_matches_matchs_draws_away  \
# 3827                                               2
# 6579                                               2
# 12643                                              1
# 14276                                              1
# 78053                                              9
#
#        teams_away_all_last_matches_matchs_loses_home  \
# 3827                                               6
# 6579                                               6
# 12643                                              0
# 14276                                              2
# 78053                                             10
#
#        teams_away_all_last_matches_matchs_loses_away  \
# 3827                                               1
# 6579                                               1
# 12643                                              1
# 14276                                              2
# 78053                                              7
#
#        teams_away_all_last_matches_goals_goalsFor_home  \
# 3827                                                18
# 6579                                                18
# 12643                                                5
# 14276                                                4
# 78053                                               40
#
#        teams_away_all_last_matches_goals_goalsFor_away  \
# 3827                                                20
# 6579                                                20
# 12643                                                1
# 14276                                                7
# 78053                                               49
#
#        teams_away_all_last_matches_goals_goalsAgainst_home  \
# 3827                                                  19
# 6579                                                  19
# 12643                                                  1
# 14276                                                  8
# 78053                                                 48
#
#        teams_away_all_last_matches_goals_goalsAgainst_away  \
# 3827                                                   9
# 6579                                                   9
# 12643                                                  2
# 14276                                                  9
# 78053                                                 41
#
#        teams_away_all_last_matches_goalsAvg_goalsFor_home  \
# 3827                                                 1.6
# 6579                                                 1.6
# 12643                                                1.7
# 14276                                                1.0
# 78053                                                1.6
#
#        teams_away_all_last_matches_goalsAvg_goalsFor_away  \
# 3827                                                 1.8
# 6579                                                 1.8
# 12643                                                0.5
# 14276                                                1.8
# 78053                                                2.0
#
#        teams_away_all_last_matches_goalsAvg_goalsAgainst_home  \
# 3827                                                 1.7
# 6579                                                 1.7
# 12643                                                0.3
# 14276                                                2.0
# 78053                                                1.9
#
#        teams_away_all_last_matches_goalsAvg_goalsAgainst_away  \
# 3827                                                 0.8
# 6579                                                 0.8
# 12643                                                1.0
# 14276                                                2.3
# 78053                                                1.6
#
#        teams_away_last_h2h_played_home  teams_away_last_h2h_played_away  \
# 3827                                 9                                9
# 6579                                 9                                9
# 12643                                0                                0
# 14276                                9                                9
# 78053                               10                               10
#
#        teams_away_last_h2h_wins_home  teams_away_last_h2h_wins_away  \
# 3827                               3                              4
# 6579                               3                              4
# 12643                              0                              0
# 14276                              3                              4
# 78053                              3                              3
#
#        teams_away_last_h2h_draws_home  teams_away_last_h2h_draws_away  \
# 3827                                2                               2
# 6579                                2                               2
# 12643                               0                               0
# 14276                               2                               2
# 78053                               4                               4
#
#        teams_away_last_h2h_loses_home  teams_away_last_h2h_loses_away outcome  \
# 3827                                4                               3   Under
# 6579                                4                               3   Under
# 12643                               0                               0    Over
# 14276                               4                               3    Over
# 78053                               3                               3    Over
#
#        fixture_year  fixture_week  fixture_day  fixture_month  fixture_weekday
# 3827           2020            42            5             10                4
# 6579           2020            42            5             10                4
# 12643          2020            47            7             11                6
# 14276          2019            34            5              8                4
# 78053          2019            19            7              5                6

# %% [markdown]
# <b>There's no way a home team will play against themselves. For this, we'll drop these rows</b>

# %%
train = train.drop(labels=[3827,6579, 12643, 14276, 78053], axis=0)

# %% [markdown]
# <h3> Feature Engineering</h3>

# %% [markdown]
# Since, the objective is to predict the total goals scored by a team in a match. For this categorical variables that define a particular team may not be useful. Variables such as stadium of the home or away team, city they are situated. Hence, we will drop them and create some numerical features that define any teams such as:
#
# 1. if the match is played in a neutral, home, or away ground.
# 2. Time match was played: Summer, Winter, Autumn, Spring

# %%
def venue_status(df):
    """This checks if the fixture venue is the teams home venue or is an away or neutral ground"""
    # replacing non-ascii numbers
    df[['fixture_venue', 'home_team_venue_name', 'away_team_venue_name']] \
    = df[['fixture_venue', 'home_team_venue_name', 'away_team_venue_name']].apply(
        lambda x: x.replace('[^a-zA-Z0-9\'\s]+', '', regex=True).str.strip())
    
    for row, num in df[['fixture_venue', 'home_team_venue_name', 'away_team_venue_name']].iterrows():
        
        
        if str(num.fixture_venue) == 'nan' or str(num.home_team_venue_name) == 'nan' or \
        str(num.away_team_venue_name) == 'nan':
            df.loc[row, 'venue_status'] = 'Unknown'
        elif str(num.away_team_venue_name).lower() in str(num.fixture_venue).lower():
            df.loc[row, 'venue_status'] = 'Away'
        elif str(num.home_team_venue_name).lower() in str(num.fixture_venue).lower():
            df.loc[row, 'venue_status'] = 'Home'
        elif str(num.away_team_venue_name).lower() not in str(num.fixture_venue).lower() and \
        str(num.away_team_venue_name).lower() not in str(num.fixture_venue).lower():
            df.loc[row, 'venue_status'] = 'Neutral'
    return df

# %%
test = venue_status(test)

# %%
valid = venue_status(valid)

# %%
train = venue_status(train)

# %%
def weather(x):
    if x in [3,4,5]: return 'spring'
    elif x in [6,7,8]: return 'summer'
    elif x in [9,10,11]: return 'fall'
    else: return 'winter'

# %%
for data_df in [train, valid, test]:
    data_df['weather_season'] = data_df.fixture_month.apply(weather)

# %%
# dropping irrelevant columns
drop_cols = ['fixture_date', 'home_team_venue_name', 'home_team_venue_city', 
             'away_team_venue_city', 'away_team_venue_name', 'home_team_venue_capacity', 
             'away_team_founded', 'home_team_founded', 'fixture_id','away_team_venue_capacity']

# %%
train.head(2)
# Out:
#    fixture_id  teams_home_team_id  teams_away_team_id  \
# 0      570479                3396                3400
# 1      102820                2788                2777
#
#                fixture_date                 fixture_venue  league_id  \
# 0 2020-10-31 00:00:00+00:00       Tsirion Athltiko Kentro       2658
# 1 2017-11-18 11:00:00+00:00  UMT Stadium Ubon Ratchathani        390
#
#            league_name league_country  league_season         league_round  \
# 0          1. Division         Cyprus           2020   Regular Season - 9
# 1  Thai Premier League       Thailand           2017  Regular Season - 34
#
#                  home_team_venue_name home_team_venue_city  \
# 0             Tsirion Athltiko Kentro              Lemesós
# 1  Udon Thani Institute of PE Stadium           Udon Thani
#
#    home_team_venue_capacity home_team_country  home_team_founded  \
# 0                   13331.0            Cyprus             1930.0
# 1                    3500.0          Thailand             2005.0
#
#          away_team_venue_name away_team_venue_city  away_team_venue_capacity  \
# 0   Dimotiko Stadio Aradippou            Aradippou                    2000.0
# 1  Sri Nakhon Lamduan Stadium              Sisaket                   12000.0
#
#   away_team_country  away_team_founded match_winner  under_over  goals_home  \
# 0            Cyprus             1958.0          1 N         NaN        -2.5
# 1          Thailand             2012.0          1 N         1.5        -2.5
#
#    goals_away  winning_percent_home  winning_percent_draws  \
# 0        -1.5                    45                     45
# 1        -2.5                    45                     45
#
#    winning_percent_away  comparison_forme_home  comparison_forme_away  \
# 0                    10                     56                     44
# 1                    10                    100                      0
#
#    comparison_att_home  comparison_att_away  comparison_def_home  \
# 0                   83                   17                   27
# 1                   50                   50                   73
#
#    comparison_def_away  comparison_fish_law_home  comparison_fish_law_away  \
# 0                   73                        61                        39
# 1                   27                         0                         0
#
#    comparison_h2h_home  comparison_h2h_away  comparison_goals_h2h_home  \
# 0                  100                    0                         73
# 1                   50                   50                         67
#
#    comparison_goals_h2h_away  teams_home_last_5_matches_forme  \
# 0                         27                               60
# 1                         33                               47
#
#    teams_home_last_5_matches_att  teams_home_last_5_matches_def  \
# 0                          100.0                           11.0
# 1                           50.0                           50.0
#
#    teams_away_last_5_matches_forme  teams_away_last_5_matches_att  \
# 0                               47                           22.0
# 1                                0                           50.0
#
#    teams_away_last_5_matches_def  teams_home_last_5_matches_goals  \
# 0                           67.0                               10
# 1                            0.0                                8
#
#    teams_home_last_5_matches_goals_avg  \
# 0                                  2.0
# 1                                  1.6
#
#    teams_home_last_5_matches_goals_against  \
# 0                                        8
# 1                                        8
#
#    teams_home_last_5_matches_goals_against_avg  \
# 0                                          1.6
# 1                                          1.6
#
#    teams_home_all_last_matches_matchs_matchsPlayed_home  \
# 0                                                  3
# 1                                                 16
#
#    teams_home_all_last_matches_matchs_matchsPlayed_away  \
# 0                                                  5
# 1                                                 17
#
#    teams_home_all_last_matches_matchs_wins_home  \
# 0                                             3
# 1                                             6
#
#    teams_home_all_last_matches_matchs_wins_away  \
# 0                                             2
# 1                                             5
#
#    teams_home_all_last_matches_matchs_draws_home  \
# 0                                              0
# 1                                              7
#
#    teams_home_all_last_matches_matchs_draws_away  \
# 0                                              0
# 1                                              4
#
#    teams_home_all_last_matches_matchs_loses_home  \
# 0                                              0
# 1                                              3
#
#    teams_home_all_last_matches_matchs_loses_away  \
# 0                                              3
# 1                                              8
#
#    teams_home_all_last_matches_goals_goalsFor_home  \
# 0                                                9
# 1                                               29
#
#    teams_home_all_last_matches_goals_goalsFor_away  \
# 0                                                5
# 1                                               24
#
#    teams_home_all_last_matches_goals_goalsAgainst_home  \
# 0                                                  3
# 1                                                 24
#
#    teams_home_all_last_matches_goals_goalsAgainst_away  \
# 0                                                  8
# 1                                                 29
#
#    teams_home_all_last_matches_goalsAvg_goalsFor_home  \
# 0                                                3.0
# 1                                                1.8
#
#    teams_home_all_last_matches_goalsAvg_goalsFor_away  \
# 0                                                1.0
# 1                                                1.4
#
#    teams_home_all_last_matches_goalsAvg_goalsAgainst_home  \
# 0                                                1.0
# 1                                                1.5
#
#    teams_home_all_last_matches_goalsAvg_goalsAgainst_away  \
# 0                                                1.6
# 1                                                1.7
#
#    teams_home_last_h2h_played_home  teams_home_last_h2h_played_away  \
# 0                                2                                2
# 1                                2                                3
#
#    teams_home_last_h2h_wins_home  teams_home_last_h2h_wins_away  \
# 0                              2                              2
# 1                              1                              1
#
#    teams_home_last_h2h_draws_home  teams_home_last_h2h_draws_away  \
# 0                               0                               0
# 1                               0                               0
#
#    teams_home_last_h2h_loses_home  teams_home_last_h2h_loses_away  \
# 0                               0                               0
# 1                               1                               2
#
#    teams_away_last_5_matches_goals  teams_away_last_5_matches_goals_avg  \
# 0                                2                                  0.4
# 1                                8                                  1.6
#
#    teams_away_last_5_matches_goals_against  \
# 0                                        3
# 1                                       22
#
#    teams_away_last_5_matches_goals_against_avg  \
# 0                                          0.6
# 1                                          4.4
#
#    teams_away_all_last_matches_matchs_matchsPlayed_home  \
# 0                                                  4
# 1                                                 17
#
#    teams_away_all_last_matches_matchs_matchsPlayed_away  \
# 0                                                  4
# 1                                                 16
#
#    teams_away_all_last_matches_matchs_wins_home  \
# 0                                             0
# 1                                             4
#
#    teams_away_all_last_matches_matchs_wins_away  \
# 0                                             3
# 1                                             2
#
#    teams_away_all_last_matches_matchs_draws_home  \
# 0                                              1
# 1                                              5
#
#    teams_away_all_last_matches_matchs_draws_away  \
# 0                                              0
# 1                                              0
#
#    teams_away_all_last_matches_matchs_loses_home  \
# 0                                              3
# 1                                              8
#
#    teams_away_all_last_matches_matchs_loses_away  \
# 0                                              1
# 1                                             14
#
#    teams_away_all_last_matches_goals_goalsFor_home  \
# 0                                                0
# 1                                               26
#
#    teams_away_all_last_matches_goals_goalsFor_away  \
# 0                                                5
# 1                                               16
#
#    teams_away_all_last_matches_goals_goalsAgainst_home  \
# 0                                                  9
# 1                                                 41
#
#    teams_away_all_last_matches_goals_goalsAgainst_away  \
# 0                                                  3
# 1                                                 47
#
#    teams_away_all_last_matches_goalsAvg_goalsFor_home  \
# 0                                                0.0
# 1                                                1.5
#
#    teams_away_all_last_matches_goalsAvg_goalsFor_away  \
# 0                                                1.3
# 1                                                1.0
#
#    teams_away_all_last_matches_goalsAvg_goalsAgainst_home  \
# 0                                                2.3
# 1                                                2.4
#
#    teams_away_all_last_matches_goalsAvg_goalsAgainst_away  \
# 0                                                0.8
# 1                                                2.9
#
#    teams_away_last_h2h_played_home  teams_away_last_h2h_played_away  \
# 0                                2                                2
# 1                                3                                2
#
#    teams_away_last_h2h_wins_home  teams_away_last_h2h_wins_away  \
# 0                              0                              0
# 1                              2                              1
#
#    teams_away_last_h2h_draws_home  teams_away_last_h2h_draws_away  \
# 0                               0                               0
# 1                               0                               0
#
#    teams_away_last_h2h_loses_home  teams_away_last_h2h_loses_away outcome  \
# 0                               2                               2    Over
# 1                               1                               1    Over
#
#    fixture_year  fixture_week  fixture_day  fixture_month  fixture_weekday  \
# 0          2020            44            6             10                5
# 1          2017            46            6             11                5
#
#   venue_status weather_season
# 0         Home           fall
# 1      Neutral           fall

# %%
# dropping irrelevant columns
train.drop(drop_cols, axis=1, inplace=True)
valid.drop(drop_cols, axis=1, inplace=True)
test.drop(drop_cols, axis=1, inplace=True)

# %%
train.shape, test.shape, valid.shape
# Out:
# ((99531, 99), (500, 98), (50000, 99))

# %%
# saving data
train.to_pickle('train_cleaned.pkl', compression='gzip')
valid.to_pickle('valid_cleaned.pkl', compression='gzip')
test.to_pickle('test_cleaned.pkl', compression='gzip')
